# %% [markdown]
# # Mi primer notebook

# %%
Este es mi primer notebook y voy a hacer lo siguiente.

# %% [markdown]
# Una lista **enumerada**
#
# 1. Primero
# 3. Segundo
# 4. Tercero

# %% [markdown]
# Una lista **por puntos**
#
# - Primero
# - Segundo
# - Tercero

# %% [markdown]
# Mi primer código:

# %%
mi_primera_frase = "Hello world"

# %% [markdown]
# __// Como cuando lo ejecuto no sale nada, tengo que usar la función print ()__
# print(mi_primera_frase)
